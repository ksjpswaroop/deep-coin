# %%
import os, sys, gc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from pandas import Series
from keras.layers import Conv1D, Dense, MaxPooling1D, Flatten
from keras.models import Sequential

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
file_path = '/root/data/btc_data.pkl'
df = pd.read_pickle(file_path)
df.tail()
# Out:
#                               Open    Close  Volume_(BTC)  Percentage_Change  \
# Timestamp
# 2017-05-30 23:56:00+00:00  2190.49  2181.37      1.700166          -0.000957
# 2017-05-30 23:57:00+00:00  2190.50  2195.63      6.561029           0.006537
# 2017-05-30 23:58:00+00:00  2195.62  2191.83     15.662847          -0.001731
# 2017-05-30 23:59:00+00:00  2195.82  2203.51     27.090309           0.005329
# 2017-05-31 00:00:00+00:00  2201.70  2208.33      9.961835           0.002187
#
#                            Expected_Return  BTC_Balance  USD_Balance  \
# Timestamp
# 2017-05-30 23:56:00+00:00            -9.12            0            0
# 2017-05-30 23:57:00+00:00             5.13            0            0
# 2017-05-30 23:58:00+00:00            -3.79            0            0
# 2017-05-30 23:59:00+00:00             7.69            0            0
# 2017-05-31 00:00:00+00:00             6.63            0            0
#
#                            Total_Balance  Return  total_rewards
# Timestamp
# 2017-05-30 23:56:00+00:00              0       0              0
# 2017-05-30 23:57:00+00:00              0       0              0
# 2017-05-30 23:58:00+00:00              0       0              0
# 2017-05-30 23:59:00+00:00              0       0              0
# 2017-05-31 00:00:00+00:00              0       0              0

# %%
df.T
# Out:
# Timestamp          2011-12-31 07:52:00+00:00  2011-12-31 15:50:00+00:00  \
# Open                                4.390000                       4.39
# Close                               4.390000                       4.39
# Volume_(BTC)                        0.455581                      48.00
# Percentage_Change                        NaN                       0.00
# Expected_Return                     0.000000                       0.00
# BTC_Balance                         0.000000                       0.00
# USD_Balance                         0.000000                       0.00
# Total_Balance                       0.000000                       0.00
# Return                              0.000000                       0.00
# total_rewards                       0.000000                       0.00
#
# Timestamp          2011-12-31 16:59:00+00:00  2011-12-31 17:00:00+00:00  \
# Open                                4.500000                   4.580000
# Close                               4.570000                   4.580000
# Volume_(BTC)                       37.862297                   9.000000
# Percentage_Change                   0.041002                   0.002188
# Expected_Return                     0.070000                   0.000000
# BTC_Balance                         0.000000                   0.000000
# USD_Balance                         0.000000                   0.000000
# Total_Balance                       0.000000                   0.000000
# Return                              0.000000                   0.000000
# total_rewards                       0.000000                   0.000000
#
# Timestamp          2012-01-01 04:16:00+00:00  2012-01-01 15:28:00+00:00  \
# Open                                   4.580                   4.840000
# Close                                  4.580                   4.840000
# Volume_(BTC)                           1.502                  10.000000
# Percentage_Change                      0.000                   0.056769
# Expected_Return                        0.000                   0.000000
# BTC_Balance                            0.000                   0.000000
# USD_Balance                            0.000                   0.000000
# Total_Balance                          0.000                   0.000000
# Return                                 0.000                   0.000000
# total_rewards                          0.000                   0.000000
#
# Timestamp          2012-01-01 22:45:00+00:00  2012-01-02 20:04:00+00:00  \
# Open                                5.000000                      5.000
# Close                               5.000000                      5.000
# Volume_(BTC)                       10.100000                     19.048
# Percentage_Change                   0.033058                      0.000
# Expected_Return                     0.000000                      0.000
# BTC_Balance                         0.000000                      0.000
# USD_Balance                         0.000000                      0.000
# Total_Balance                       0.000000                      0.000
# Return                              0.000000                      0.000
# total_rewards                       0.000000                      0.000
#
# Timestamp          2012-01-03 11:45:00+00:00  2012-01-03 14:22:00+00:00  \
# Open                                5.320000                   5.140000
# Close                               5.320000                   5.140000
# Volume_(BTC)                        2.419173                   0.680000
# Percentage_Change                   0.064000                  -0.033835
# Expected_Return                     0.000000                   0.000000
# BTC_Balance                         0.000000                   0.000000
# USD_Balance                         0.000000                   0.000000
# Total_Balance                       0.000000                   0.000000
# Return                              0.000000                   0.000000
# total_rewards                       0.000000                   0.000000
#
# Timestamp                    ...              2017-05-30 23:51:00+00:00  \
# Open                         ...                            2171.380000
# Close                        ...                            2173.000000
# Volume_(BTC)                 ...                              41.201953
# Percentage_Change            ...                               0.000741
# Expected_Return              ...                               1.620000
# BTC_Balance                  ...                               0.000000
# USD_Balance                  ...                               0.000000
# Total_Balance                ...                               0.000000
# Return                       ...                               0.000000
# total_rewards                ...                               0.000000
#
# Timestamp          2017-05-30 23:52:00+00:00  2017-05-30 23:53:00+00:00  \
# Open                             2173.000000                2190.990000
# Close                            2189.620000                2189.410000
# Volume_(BTC)                       26.256615                   2.028020
# Percentage_Change                   0.007648                  -0.000096
# Expected_Return                    16.620000                  -1.580000
# BTC_Balance                         0.000000                   0.000000
# USD_Balance                         0.000000                   0.000000
# Total_Balance                       0.000000                   0.000000
# Return                              0.000000                   0.000000
# total_rewards                       0.000000                   0.000000
#
# Timestamp          2017-05-30 23:54:00+00:00  2017-05-30 23:55:00+00:00  \
# Open                             2189.600000                2183.310000
# Close                            2190.960000                2183.460000
# Volume_(BTC)                        1.389392                   5.639300
# Percentage_Change                   0.000708                  -0.003423
# Expected_Return                     1.360000                   0.150000
# BTC_Balance                         0.000000                   0.000000
# USD_Balance                         0.000000                   0.000000
# Total_Balance                       0.000000                   0.000000
# Return                              0.000000                   0.000000
# total_rewards                       0.000000                   0.000000
#
# Timestamp          2017-05-30 23:56:00+00:00  2017-05-30 23:57:00+00:00  \
# Open                             2190.490000                2190.500000
# Close                            2181.370000                2195.630000
# Volume_(BTC)                        1.700166                   6.561029
# Percentage_Change                  -0.000957                   0.006537
# Expected_Return                    -9.120000                   5.130000
# BTC_Balance                         0.000000                   0.000000
# USD_Balance                         0.000000                   0.000000
# Total_Balance                       0.000000                   0.000000
# Return                              0.000000                   0.000000
# total_rewards                       0.000000                   0.000000
#
# Timestamp          2017-05-30 23:58:00+00:00  2017-05-30 23:59:00+00:00  \
# Open                             2195.620000                2195.820000
# Close                            2191.830000                2203.510000
# Volume_(BTC)                       15.662847                  27.090309
# Percentage_Change                  -0.001731                   0.005329
# Expected_Return                    -3.790000                   7.690000
# BTC_Balance                         0.000000                   0.000000
# USD_Balance                         0.000000                   0.000000
# Total_Balance                       0.000000                   0.000000
# Return                              0.000000                   0.000000
# total_rewards                       0.000000                   0.000000
#
# Timestamp          2017-05-31 00:00:00+00:00
# Open                             2201.700000
# Close                            2208.330000
# Volume_(BTC)                        9.961835
# Percentage_Change                   0.002187
# Expected_Return                     6.630000
# BTC_Balance                         0.000000
# USD_Balance                         0.000000
# Total_Balance                       0.000000
# Return                              0.000000
# total_rewards                       0.000000
#
# [10 rows x 1650904 columns]

# %%
initial_bal = 1000
num_steps = 1000000

# %%
# model's hyperparameters
window_size = 60
nb_filter = 10
filter_length = 10
nb_input_series = 10
nb_outputs = 2
epochs = 1
batch_size = 1

# %%
def reward_function(previous_state_value, current_state_value):
    reward = current_state_value - previous_state_value
    return loss

# %%
def build_convolution1D_model(window_size, filter_length, nb_input_series=1, nb_outputs=1, nb_filter=4):
    model = Sequential((
        Conv1D(filters=nb_filter, kernel_size=filter_length, activation='relu', input_shape=(window_size, nb_input_series)),
        MaxPooling1D(), # Downsample the output of convolution by 2X.
        Conv1D(filters=nb_filter, kernel_size=filter_length, activation='relu'),
        MaxPooling1D(),
        Flatten(),
        Dense(nb_outputs, activation='relu'), 
        ))
    
    model.compile(loss=loss, optimizer='adam', metrics=[loss]) 
    return model

# %%
step = 0
Y = np.zeros((1, 2))
X = df[step:step + window_size].as_matrix()
X_nxt = df[1:1 + window_size].as_matrix()
X = np.reshape(X, (1, 60, 10))
X_nxt = np.reshape(X_nxt, (1, 60, 10))
print (X.shape)
# Out:
# (1, 60, 10)

# %%
# build the model and print the summary of the model
model = build_convolution1D_model(window_size=window_size, filter_length=filter_length, nb_input_series=nb_input_series, nb_outputs=nb_outputs, nb_filter=nb_filter)
print('\n\nModel with input size {}, output size {}, {} conv filters of length {}'.format(model.input_shape, model.output_shape, nb_filter, filter_length))
model.summary()
# Out:
# Model with input size (None, 60, 10), output size (None, 2), 10 conv filters of length 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_5 (Conv1D)            (None, 51, 10)            1010
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 25, 10)            0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 16, 10)            1010
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 8, 10)             0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 80)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 162
# =================================================================
# Total params: 2,182
# Trainable params: 2,182
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x=X_train, y=Y_train, batch_size=60, epochs=1, verbose=2, validation_data=None, shuffle=False)
# Out:
# Epoch 1/1
# 1s - loss_1: -1.0000e+00 - loss_2: -1.0000e+00
